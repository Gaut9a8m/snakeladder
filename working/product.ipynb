# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv(
'product_404.log',
usecols=[0, 1,3,5, 6, 7, 8, 10, 11, 17],
sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',
delimiter=None, engine='python',
names=['Domain','IP','Time-Stamp','Response-Time','Host','Request','Status','Referer', 'User-Agent', 'X-IP']
)

# %%
df
# Out:
#                    Domain              IP            Time-Stamp  \
# 0      www.tradeindia.com  64.252.168.139  14/Feb/2022:00:00:10
# 1      www.tradeindia.com  64.252.151.145  14/Feb/2022:00:01:07
# 2      www.tradeindia.com  64.252.151.145  14/Feb/2022:00:01:09
# 3      www.tradeindia.com  64.252.151.145  14/Feb/2022:00:01:19
# 4      www.tradeindia.com  130.176.98.148  14/Feb/2022:00:01:53
# ...                   ...             ...                   ...
# 13105  www.tradeindia.com  130.176.179.14  14/Feb/2022:23:58:46
# 13106  www.tradeindia.com  130.176.98.148  14/Feb/2022:23:58:59
# 13107  www.tradeindia.com    15.158.10.70  14/Feb/2022:23:59:02
# 13108  www.tradeindia.com  130.176.179.14  14/Feb/2022:23:59:26
# 13109  www.tradeindia.com    15.158.16.84  14/Feb/2022:23:59:51
#
#                   Response-Time                       Host  \
# 0      --0.052/1644777010.106--  Host:"www.tradeindia.com"
# 1      --0.059/1644777067.417--  Host:"www.tradeindia.com"
# ...

# %%
tmp_df = df[['Request','User-Agent','X-IP', 'Referer']]
bot_df = tmp_df.loc[tmp_df['User-Agent'].str.contains('bot')==True]
google_bot_df = tmp_df.loc[tmp_df['User-Agent'].str.contains('GoogleBot', case=False)==True]
bing_bot_df = tmp_df.loc[tmp_df['User-Agent'].str.contains('BingBot',case=False)==True]
human_df = tmp_df.loc[tmp_df['User-Agent'].str.contains('bot')==False]

# %%
bing_bot_df_c = bing_bot_df.loc[bing_bot_df['Request'].str.contains('-c[0-9]+', case=False)==True]
bing_bot_df_wc = bing_bot_df.loc[bing_bot_df['Request'].str.contains('-c[0-9]+', case=False)==False]
google_bot_df_c = google_bot_df.loc[google_bot_df['Request'].str.contains('-c[0-9]+', case=False)==True]
google_bot_df_wc = google_bot_df.loc[google_bot_df['Request'].str.contains('-c[0-9]+', case=False)==False]
human_df_c = human_df.loc[human_df['Request'].str.contains('-c[0-9]+', case=False)==True]
human_df_wc = human_df.loc[human_df['Request'].str.contains('-c[0-9]+', case=False)==False]

# %%
bing_bot_df_wc
# Out:
#                                                  Request  \
# 9        "GET /products/plc-panels-900734.html HTTP/1.1"
# 17     "GET /products/fully-automatic-and-rust-resist...
# 21        "GET /products/coriander-982062.html HTTP/1.1"
# 24     "GET /products/control-transformers-976739.htm...
# 26          "GET /products/channel-823304.html HTTP/1.1"
# ...                                                  ...
# 13035   "GET /products/formic-acid-992512.html HTTP/1.1"
# 13050   "GET /products/adipic-acid-995116.html HTTP/1.1"
# 13076  "GET /products/pure-natural-green-cardamom-711...
# 13095   "GET /products/welded-mesh-874894.html HTTP/1.1"
# 13100  "GET /products/sculptra-2-vials-dermal-filler-...
#
#                                               User-Agent            X-IP  \
# 9      "Mozilla/5.0 (compatible; bingbot/2.0; +http:/...  157.55.39.185,
# 17     "Mozilla/5.0 (compatible; bingbot/2.0; +http:/...   40.77.167.24,
# ...

# %%
human_df_c.groupby(['X-IP','Request'])['Request'].agg(count = 'count').sort_values('count',ascending=False)
# .to_csv('human_cp_404_IP_count.csv')
# human_df_wc.groupby(['X-IP'])['Request'].agg(count = 'count').sort_values('count',ascending=False).to_csv('human_fp_404_IP_count.csv')
# Out:
#                                                                     count
# X-IP            Request
# -               "GET /products/chanderi-silk-saree-c5160410.htm...      5
# 197.210.29.102, "GET /products/n-female-4-hole-connector-for-rg...      5
#                 "GET /products/n-female-4-hole-connector-for-rg...      4
# 13.232.143.232, "GET /products/freemans-measuring-tape-c6564680...      4
#                 "GET /products/metal-badges-c2576239.html HTTP/...      4
# ...                                                                   ...
# 20.109.241.81,  "GET /products/lg-260-l-frost-free-double-door-...      1
#                 "GET /products/electric-tow-tractor-c6141758.ht...      1
#                 "GET /products/concrete-thermometer-c4407361.ht...      1
#                 "GET /products/betamethasone-base-c330391.html ...      1
# 99.120.89.248,  "GET /products/one-piece-bottom-inlet-dual-flus...      1
#
# [512 rows x 1 columns]

# %%
bing_bot_df_c
google_bot_df_c
human_df_c
bing_bot_df_wc
google_bot_df_wc
human_df_wc
# Out:
#                                                  Request  \
# 0      "GET /products/long-grain-white-basmati-rice-6...
# 41     "GET /products/noodles-machines-4149507.html H...
# 54     "GET /products/cute-doberman-puppies-5402190.h...
# 67     "GET /products/organic-fresh-green-peas-635553...
# 158    "GET /products/%20titanium%20-%20ore%20-515394...
# ...                                                  ...
# 13098  "GET /fp225471/ConRoe945G-DVI-Mother-Boards.ht...
# 13101  "GET /fp906417/Vehicle-Tracking-System.html/pr...
# 13102  "GET /fp225466/ZION-USB-Flash-Drive.html/produ...
# 13107  "GET /products/interface-level-indicator-20899...
# 13109  "GET /fp625242/Educational-Abacus.html/product...
#
#                                               User-Agent              X-IP  \
# 0      "node-fetch/1.0 (+https://github.com/bitinn/no...   107.178.237.25,
# 41     "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_...    20.109.241.82,
# ...

# %%
google_bot_df_c.groupby(['X-IP'])['Request'].agg(count = 'count').sort_values('count',ascending=False)
# .to_csv('google_cp_404_IP_count.csv')
google_bot_df_wc.groupby(['X-IP'])['Request'].agg(count = 'count').sort_values('count',ascending=False)
# .to_csv('google_fp_404_IP_count.csv')
bing_bot_df_c.groupby(['X-IP'])['Request'].agg(count = 'count').sort_values('count',ascending=False)
# .to_csv('bing_cp_404_IP_count.csv')
bing_bot_df_wc.groupby(['X-IP'])['Request'].agg(count = 'count').sort_values('count',ascending=False)
# .to_csv('bing_fp_404_IP_count.csv')
# Out:
#                                                                    count
# X-IP           Request
# 40.77.167.24,  "GET /products/town.php/ HTTP/1.1"                      4
# 207.46.13.100, "GET /products/town.php/ HTTP/1.1"                      3
# 157.55.39.185, "GET /products/amul-cheese-3615050.html HTTP/1.1"       3
# 207.46.13.100, "GET /products/memory-card-with-adapter-3840144...      2
# 207.46.13.156, "GET /products/aluminum-truss-6035231.html HTTP...      2
# ...                                                                  ...
# 207.46.13.100, "GET /products/vacuum-pump-971092.html HTTP/1.1"        1
#                "GET /products/valve-castings-890621.html HTTP/...      1
#                "GET /products/valve-guides-846497.html HTTP/1.1"       1
#                "GET /products/viscose-yarn-967980.html HTTP/1.1"       1
# 40.77.167.24,  "GET /products/zipper-bags-947203.html HTTP/1.1"        1
#
# [3237 rows x 1 columns]

# %%
google_bot_df_c.groupby(['Request'])['Request'].agg(count = 'count').sort_values('count',ascending=False)
# .to_csv('google_cp_404_urls_count.csv')
google_bot_df_wc.groupby(['Request'])['Request'].agg(count = 'count').sort_values('count',ascending=False)
# .to_csv('google_fp_404_urls_count.csv')
# bing_bot_df_c.groupby(['Request'])['Request'].agg(count = 'count').sort_values('count',ascending=False)
# .to_csv('bing_cp_404_urls_count.csv')
# bing_bot_df_wc.groupby(['Request'])['Request'].agg(count = 'count').sort_values('count',ascending=False)
# .to_csv('bing_fp_404_urls_count.csv')
# human_df_c.groupby(['Request'])['Request'].agg(count = 'count').sort_values('count',ascending=False)
# .to_csv('human_cp_404_url_count.csv')
# human_df_wc.groupby(['Request'])['Request'].agg(count = 'count').sort_values('count',ascending=False)
# .to_csv('human_fp_404_url_count.csv')
# Out:
#                                                     count
# Request
# "GET /products/designer-wedding-lehenga-choli-6...      8
# "GET /products/classic-gold-furniture-sofa-set-...      7
# "GET /products/er-india-g7-rickshaw-4226763.htm...      6
# "GET /products/dot-matrix-printer-5674398.html ...      6
# "GET /products/power-bike-ktm-rc-200-4558674.ht...      5
# ...                                                   ...
# "GET /products/fancy-bell-1708913.html HTTP/1.1"        1
# "GET /products/facial-hair-remover-for-travel-6...      1
# "GET /products/export-quality-zahidi-wet-dates-...      1
# "GET /products/export-quality-pebble-wash-floor...      1
# "GET /products/industrial-automatic-sand-dryer-...      1
#
# [1713 rows x 1 columns]

# %%
human_df_wc.loc[human_df_wc['Request'].str.contains('/products/ARRAY-', case=False)==True]
# Out:
# Empty DataFrame
# Columns: [Request, User-Agent, X-IP, Referer]
# Index: []
